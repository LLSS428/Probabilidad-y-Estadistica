# %% [markdown]
# <a href="https://colab.research.google.com/github/LLSS428/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
# ## **Unidad 1**
# ### **Grupo 2 Y**
# ### **Practica 3: Tabla de frecuencias y regla de Sturges**
# ### Docente: Jose Gabriel Rodriguez Rivas
# ### Alumno: Leonel Alberto Ontiveros Vera

# %%
import random
# Vector que va a contener 100 edades generadas aleatoriamente
edades=[]
for x in range(100):
  #Rango de edades entre 18 y 70 años
  rdm=random.randint(18,70)
  edades.append(rdm)
print(edades)
# Out:
# [59, 23, 55, 60, 61, 49, 38, 60, 23, 46, 41, 46, 44, 56, 28, 28, 42, 68, 66, 37, 25, 60, 20, 20, 30, 57, 45, 59, 25, 50, 53, 59, 53, 29, 58, 60, 36, 21, 52, 32, 65, 41, 67, 19, 18, 29, 34, 67, 27, 30, 59, 26, 50, 44, 57, 59, 47, 55, 19, 32, 38, 67, 31, 42, 22, 22, 55, 25, 18, 53, 37, 24, 70, 58, 63, 42, 28, 38, 43, 42, 46, 48, 28, 64, 58, 53, 28, 19, 22, 62, 31, 38, 40, 37, 55, 33, 66, 56, 40, 19]

# %%
# Con el paquete de pandas se hace un data frame con los numeros aleatorios
import pandas as pd
df=pd.DataFrame(edades,columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    59
# 1    23
# 2    55
# 3    60
# 4    61

# %%
# Se va a calcular la tabla de disrtibución de frecuencias
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 26    18           2
# 6     19           4
# 27    20           2
# 34    21           1
# 10    22           3
# 21    23           2
# 40    24           1
# 8     25           3
# 36    26           1
# 37    27           1
# 1     28           5
# 17    29           2
# 22    30           2
# 25    31           2
# 18    32           2
# 47    33           1
# 39    34           1
# 33    36           1
# 13    37           3
# 5     38           4
# 24    40           2
# 20    41           2
# 4     42           4
# 42    43           1
# 15    44           2
# 31    45           1
# 12    46           3
# 38    47           1
# 44    48           1
# 30    49           1
# 16    50           2
# 35    52           1
# 7     53           4
# 3     55           4
# 14    56           2
# 23    57           2
# 9     58           3
# 0     59           5
# 2     60           4
# 29    61           1
# ...
