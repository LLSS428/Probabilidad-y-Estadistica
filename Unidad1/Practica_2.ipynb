# %% [markdown]
# <a href="https://colab.research.google.com/github/LLSS428/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estadistica**
# ## Grupo 2 Y
# ## Unidad 1
# Docente: Jose Gabriel Rodriguez Rivas
#
# ---
#
#
# Alumno: Leonel Alberto Ontiveros Vera
#
# ---
#
#
# **Practica 2: Máximo, Minimo, Rango y Dispersión de datos**

# %%
import random
import matplotlib.pyplot as grf
from statistics import*

# %%
fabrica1=[]
for x in range(100):
  rdm1=round (random.uniform(50,100),2)
  fabrica1.append(rdm1)
print(fabrica1)
# Out:
# [52.03, 85.75, 83.29, 90.48, 79.8, 59.66, 96.17, 71.74, 86.26, 50.29, 88.63, 75.2, 94.31, 76.8, 50.49, 81.12, 98.73, 70.09, 82.45, 58.76, 52.48, 89.89, 55.09, 62.61, 65.6, 71.39, 62.72, 87.59, 65.48, 64.56, 62.2, 59.3, 66.48, 89.58, 62.94, 92.28, 85.77, 89.99, 97.23, 67.25, 95.95, 94.21, 73.85, 64.7, 92.32, 68.71, 99.51, 64.31, 62.37, 57.98, 74.32, 50.76, 57.11, 55.77, 68.13, 63.24, 89.03, 67.56, 78.14, 75.1, 80.0, 62.16, 96.41, 88.98, 50.61, 53.22, 67.41, 55.62, 73.03, 70.49, 75.28, 59.96, 60.94, 84.39, 55.28, 79.62, 54.74, 91.79, 83.47, 83.21, 85.43, 61.12, 81.89, 74.27, 90.77, 79.85, 88.21, 58.9, 63.04, 92.43, 96.16, 57.7, 60.53, 94.8, 66.15, 76.82, 54.31, 63.85, 52.94, 85.99]

# %%
fabrica2=[]
for x in range(100):
  rdm2=round (random.uniform(40,93),2)
  fabrica2.append(rdm2)
print(fabrica1)
# Out:
# [52.03, 85.75, 83.29, 90.48, 79.8, 59.66, 96.17, 71.74, 86.26, 50.29, 88.63, 75.2, 94.31, 76.8, 50.49, 81.12, 98.73, 70.09, 82.45, 58.76, 52.48, 89.89, 55.09, 62.61, 65.6, 71.39, 62.72, 87.59, 65.48, 64.56, 62.2, 59.3, 66.48, 89.58, 62.94, 92.28, 85.77, 89.99, 97.23, 67.25, 95.95, 94.21, 73.85, 64.7, 92.32, 68.71, 99.51, 64.31, 62.37, 57.98, 74.32, 50.76, 57.11, 55.77, 68.13, 63.24, 89.03, 67.56, 78.14, 75.1, 80.0, 62.16, 96.41, 88.98, 50.61, 53.22, 67.41, 55.62, 73.03, 70.49, 75.28, 59.96, 60.94, 84.39, 55.28, 79.62, 54.74, 91.79, 83.47, 83.21, 85.43, 61.12, 81.89, 74.27, 90.77, 79.85, 88.21, 58.9, 63.04, 92.43, 96.16, 57.7, 60.53, 94.8, 66.15, 76.82, 54.31, 63.85, 52.94, 85.99]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Estadistica descriptiva de la fabrica1 1","\nMedia =",media1,"\nMediana =",
      mediana1,"\nModa =",moda1, "\nMáximo =",maximo1,
      "\nMinimo =",minimo1,"\nRango =",rango1)
# Out:
# Estadistica descriptiva de la fabrica1 1
# Media = 73.4732
# Mediana = 72.38499999999999
# Moda = 52.03
# Máximo = 99.51
# Minimo = 50.29
# Rango = 49.220000000000006

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo1-minimo1
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Estadistica descriptiva de la fabrica1 1","\nMedia =",media2,"\nMediana =",
      mediana2,"\nModa =",moda2, "\nMáximo =",maximo1,
      "\nMinimo =",minimo2,"\nRango =",rango2)
# Out:
# Estadistica descriptiva de la fabrica1 1
# Media = 67.1445
# Mediana = 66.815
# Moda = 40.87
# Máximo = 99.51
# Minimo = 40.16
# Rango = 49.220000000000006

# %%
# stdev es el metodo para sacar la desviación estandar
desviacion_estandar_fabrica1=stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.412400306189756

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 15.787611520595904

# %%
grf.figure(figsize=(8,6))
grf.hist(fabrica1,bins=10,alpha=0.2,color='b',edgecolor="black")
grf.axvline(media1,color='b',linestyle='dashed',linewidth=2,label=f'Media={media1:.2f}')
grf.axvline(mediana1,color='r',linestyle='dashed',linewidth=2,label=f'Mediana={mediana1:.2f}')
grf.axvline(moda1,color='y',linestyle='dashed',linewidth=2,label=f'Moda={moda1:.2f}')
grf.axvline(media1-desviacion_estandar_fabrica1,color='black',linestyle='dashed',linewidth=2,label=f'Desv. Estandar={desviacion_estandar_fabrica1:.2f}')
grf.axvline(media1+desviacion_estandar_fabrica1,color='black',linestyle='dashed',linewidth=2)
grf.xlabel('Valor')
grf.ylabel('Frecuencia')
grf.title("Producción diaria de la fabrica 1")
grf.legend()
grf.show()

# %%
grf.figure(figsize=(8,6))
grf.hist(fabrica2,bins=10,alpha=0.2,color='b',edgecolor="black")
grf.axvline(media2,color='b', linestyle='dashed',linewidth=2,label=f'Media={media2:.2f}')
grf.axvline(mediana2,color='r',linestyle='dashed',linewidth=2,label=f'Mediana={mediana2:.2f}')
grf.axvline(moda2,color='y',linestyle='dashed',linewidth=2,label=f'Moda={moda2:.2f}')
grf.axvline(media2-desviacion_estandar_fabrica2,color='black',linestyle='dashed',linewidth=2,label=f'Desv. Estandar={desviacion_estandar_fabrica2:.2f}')
grf.axvline(media2+desviacion_estandar_fabrica2,color='black',linestyle='dashed',linewidth=2)
grf.xlabel('Valor')
grf.ylabel('Frecuencia')
grf.title("Producción diaria de la fabrica 1")
grf.legend()
grf.show()

# %%
import seaborn as sns

# %%
# La densidad gráfica es una forma de visualizar la distribución de datos en
# un intervalo o periodo continuo.
# Se basa en un histograma que ua el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución
sns.histplot(x=fabrica1,kde=True,kde_kws={'bw_adjust':0.5},bins=10)
# Out:
# <Axes: ylabel='Count'>
