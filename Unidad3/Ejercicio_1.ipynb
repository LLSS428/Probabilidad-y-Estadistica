# %% [markdown]
# <a href="https://colab.research.google.com/github/LLSS428/Probabilidad-y-Estadistica/blob/main/Unidad3/Ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
# ## Unidad 3
# ### Ejercicio 1
# ### Profesor: José Gabriel Rodriguez Rivas
# ### Alumno: Leonel Alberto Ontiveros Vera

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# Valores de la variable aleatoria
x = [0, 1, 2 , 3, 4, 5]
p = [0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))

valor_esperado=0
for i in range(len(x)):
    xi = x[i]
    pi = p[i]
    producto = xi * pi
    valor_esperado += producto
    print(f"x= {xi}, p={pi}, x*p={producto:.2f}")
print (f"\nValor esperado (Esperanza): {valor_esperado:.2f}")

# Calcular E(X)
esperanza=0
for i in range(len(x)):
    esperanza += x[i] * p[i]
# Calcular E(x'2)
esperanza_cuadrado=0
for i in range(len(x)):
    esperanza_cuadrado += (x[i] ** 2) * p[i]
# Calcular la varianza y desviación estandar
varianza = esperanza_cuadrado - (esperanza ** 2)
desviación = math.sqrt(varianza)
# Mostrar resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza}")
print(f"Desviación estandar = {desviación:.2f}")

# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Num. Células")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
print("\n")

x = np.array([0, 1, 2 , 3, 4, 5])
p = np.array([0.10, 0.25, 0.30, 0.20, 0.10, 0.05])

# Cálculo del valor esperado (media)
esperanza = np.sum(x * p)

# Cálculo de la esperanza del cuadrado
esperanza_cuadrado = np.sum(x**2 * p)

# Cálculo de la varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = np.sqrt(varianza)

# Mostrar los resultados en consola
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")
print("\n")

# Crear la gráfica tipo 'stem' (tallos y hojas)
plt.stem(x, p, basefmt="", linefmt='b-', markerfmt='bo')
plt.title("Distribución de Probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("Valores de la variable aleatoria X")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)

# Dibujar línea vertical en la media
plt.axvline(x=esperanza, color='red', linestyle='--', label=f"Media (E[X]) = {esperanza:.2f}")

# Resaltar el rango de ±1 desviación estándar
plt.axvspan(esperanza - desviacion, esperanza + desviacion, color='red', alpha=0.2,
            label=f"±1 Desv. Estándar ($\sigma$ = {desviacion:.2f})")

# Mostrar leyenda y límites
plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)

# Mostrar la gráfica
plt.show()
# Out:
# Suma de probabilidades: 1.0
# x= 0, p=0.1, x*p=0.00
# x= 1, p=0.25, x*p=0.25
# x= 2, p=0.3, x*p=0.60
# x= 3, p=0.2, x*p=0.60
# x= 4, p=0.1, x*p=0.40
# x= 5, p=0.05, x*p=0.25
#
# Valor esperado (Esperanza): 2.10
# E(X) = 2.10
# E(X^2) = 6.10
# Varianza = 1.6899999999999995
# Desviación estandar = 1.30
# <>:77: SyntaxWarning: invalid escape sequence '\s'
# <>:77: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-3734041428.py:77: SyntaxWarning: invalid escape sequence '\s'
#   label=f"±1 Desv. Estándar ($\sigma$ = {desviacion:.2f})")
# E(X) = 2.10
# E(X^2) = 6.10
# Varianza = 1.69
# Desviación estándar = 1.30
