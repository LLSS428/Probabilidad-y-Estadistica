# %% [markdown]
# <a href="https://colab.research.google.com/github/LLSS428/Probabilidad-y-Estadistica/blob/main/Unidad3/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
# ## Unidad 3
# ### Practica 4
# ### Profesor: José Gabriel Rodriguez Rivas
# ### Alumno: Leonel Alberto Ontiveros Vera

# %%
# Gráfica de una distribución de probabilidad discreta
# con media, varianza y desviación estándar

import matplotlib.pyplot as plt
import numpy as np

# Datos: valores de la variable aleatoria y sus probabilidades
x = np.array([1, 2, 3, 4, 5])
p = np.array([0.05, 0.10, 0.20, 0.30, 0.35]) # Corrected: x has 5 elements, p must have 5 elements
                                                    # The probabilities now sum to 1 (0.05 + 0.10 + 0.20 + 0.30 + 0.35 = 1.00)

# Cálculo del valor esperado (media)
esperanza = np.sum(x * p)

# Cálculo de la esperanza del cuadrado
esperanza_cuadrado = np.sum(x**2 * p)

# Cálculo de la varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = np.sqrt(varianza)

# Mostrar los resultados en consola
print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")

# Crear la gráfica tipo 'stem' (tallos y hojas)
plt.stem(x, p, linefmt='--r', markerfmt='Dk', basefmt='b')
plt.title("Distribución de Probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("X (Variable aleatoria X)")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)

# Dibujar línea vertical en la media
plt.axvline(x=esperanza, color='red', linestyle='-', label=f"Media E(X) = {esperanza:.2f}")

# Resaltar el rango de ±1 desviación estándar
plt.axvspan(esperanza - desviacion, esperanza + desviacion, color='red', alpha=0.2,
            label=f"±1 Desv. Estándar ($\sigma$ = {desviacion:.2f})")

plt.legend()
plt.ylim(0, p.max() * 1.05)
plt.xticks(x)

# Mostrar la gráfica
plt.show()
# Out:
# <>:40: SyntaxWarning: invalid escape sequence '\s'
# <>:40: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-3620640037.py:40: SyntaxWarning: invalid escape sequence '\s'
#   label=f"±1 Desv. Estándar ($\sigma$ = {desviacion:.2f})")
# E(X) = 3.80
# E(X^2) = 15.80
# Varianza = 1.36
# Desviación estándar = 1.17
