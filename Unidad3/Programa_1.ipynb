# %% [markdown]
# <a href="https://colab.research.google.com/github/LLSS428/Probabilidad-y-Estadistica/blob/main/Unidad3/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
# ## Unidad 3
# ### Problema 3
# ### Profesor: José Gabriel Rodriguez Rivas
# ### Alumno: Leonel Alberto Ontiveros Vera

# %%
import matplotlib.pyplot as plt
# Valores de la variable aleatoria
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Graficar distribución
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Calificación")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades: 1.0
