# %% [markdown]
# <a href="https://colab.research.google.com/github/LLSS428/Probabilidad-y-Estadistica/blob/main/Unidad4/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
# ## Unidad 4
# ### Practica 1
# ### Profesor: José Gabriel Rodriguez Rivas
# ### Alumno: Leonel Alberto Ontiveros Vera

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generar datos para la distribución normal
media = 70       # Media
desv_std = 4     # Desviación estándar
num_datos = 500

# Generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]  # Mostrar los primeros 50
# Out:
# array([71.18804052, 67.91362577, 73.95283358, 67.71884793, 69.7079919 ,
#        71.78356064, 63.83450156, 65.19480553, 71.24821089, 72.33974182,
#        67.86872517, 72.33331013, 70.27145824, 68.17612348, 72.69275742,
#        67.54099955, 71.95968338, 72.04830391, 72.55203623, 71.86923483,
#        72.53616535, 74.22164751, 66.68609442, 69.68848551, 78.31690557,
#        67.15602137, 69.94236504, 72.03263207, 73.53285698, 67.41191625,
#        67.06077272, 74.27944318, 71.87693712, 65.06192146, 66.4147599 ,
#        72.58997171, 68.64405773, 76.88553571, 71.78742025, 73.20471983,
#        68.28060672, 71.55583646, 69.29844234, 68.52812708, 66.12010923,
#        71.27627301, 72.89339886, 76.66615686, 68.30706895, 66.83919246])

# %%
# Crear un rango de valores para crear una densidad
# El rango va de la media - 3*desv_std hasta la media + 3*desv_std
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)

# Calcular la PDF de la distribución normal (fórmula explícita, aunque 'norm.pdf' lo hace más fácil)
# pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp( - (x - media)**2 / (2 * desv_std**2))
# Usando scipy para el cálculo:
pdf = norm.pdf(x, media, desv_std)

# Para no imprimir toda la lista de valores (500), desplegamos los primeros 50
print("Imprimir los primeros 50 Valores de x", x[0:50], ", y los primeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 Valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343] , y los primeros 50 pdf [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
# ...

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b') # Histograma de los datos
plt.title('Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
# Visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal({media: .1f}; $\sigma$: {ds: .1f})'.format(media=np.round(media, 2), ds=np.round(desv_std, 2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt.xlabel('Pesos en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1120932090.py:3: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, pdf, label='Normal({media: .1f}; $\sigma$: {ds: .1f})'.format(media=np.round(media, 2), ds=np.round(desv_std, 2)))

# %%
# Graficar histograma combinado
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b') # Histograma de los datos, con densidad=True
plt.plot(x, pdf, 'k', linewidth=2) # Curva de la PDF
plt.title('Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()
